# %%
def dicmaker(file):
    newdic = {}
    file = open(file, 'r')
    for line in file.readlines():
        if len(line) > 1:
            key, item = line.split(',')[0], line.split(',')[1]
            print(key, item)
            newdic[key] = item
    return newdic

# %%
newdyft= dicmaker('dyft')
# Out:
# αι  aj
#
# αἰ  aj
#
# αἱ  haj
#
# αἴ  aj
#
# αἵ  haj
#
# αἷ  haj
#
# αἶ  aj
#
# αὐ  au
#
# αὑ  hau
#
# αὔ  au
#
# αὕ  hau
#
# αὗ  hau
#
# αὖ  au
#
# ηὐ  eu
#
# ηὑ  heu
#
# ηὗ  heu
#
# ηὖ  eu
#
# εἰ  ej
#
# εἱ  hej
#
# εἷ  hej
#
# εἶ  ej
#
# εἴ  ej
#
# εἵ  hej
#
# εὐ  eu
#
# εὑ  heu
#
# εὗ  heu
#
# εὖ  eu
#
# εὔ  eu
#
# εὕ  heu
#
# οι  oj
#
# οἱ  hoj
#
# οἰ  oj
#
# οἵ  hoj
#
# οἴ  oj
#
# οῖ  oj
#
# οἶ  oj
#
# ου  u
#
# οὺ  u
#
# οὔ  u
#
# οὖ  u
#
# οὗ  hu
#
# οὕ  hu
#
# υἰ  yj
#
# υἵ  hyj
#
# υἷ  hyj
#
# υῖ  yj
#
# αι  aj
#
# αἰ  aj
#
# αἱ  haj
#
# αἴ  aj
#
# αἵ  haj
#
# αἲ  aj
#
# αἳ  haj
#
# αἷ  haj
#
# αἶ  aj
#
# αί  aj
#
# αὶ  aj
#
# αῖ  aj
#
# αὐ  au
#
# αὑ  hau
#
# αὔ  au
#
# αὕ  hau
#
# αὒ  au
#
# αὓ  hau
#
# αὗ  hau
#
# αὖ  au
#
# αύ  au
#
# αὺ  au
#
# αῦ  au
#
# ηυ  eu
#
# ηύ  eu
#
# ηὺ  eu
#
# ηῦ  eu
#
# ηὐ  eu
#
# ηὑ  heu
#
# ηὗ  heu
#
# ηὖ  eu
#
# ηὕ  eu
#
# ηὔ  eu
#
# ει  ej
#
# εί  ej
#
# εὶ  ej
#
# εῖ  ej
#
# εἰ  ej
#
# εἱ  hej
#
# εἷ  hej
#
# εἶ  ej
#
# εἴ  ej
#
# ...

# %%
from slownik import podstawowy, przydechy, dyftongi, dicmaker

# %%
newdyft = slownik.dicmaker('dyft')

# %%
for key in newdyft:
    newitem = ''.join(newdyft[key].split())
    newdyft[key] = newitem

# %%
newdyft
# Out:
# {'αί': 'aj',
#  'αι': 'aj',
#  'αύ': 'au',
#  'αἰ': 'aj',
#  'αἱ': 'haj',
#  'αἲ': 'aj',
#  'αἳ': 'haj',
#  'αἴ': 'aj',
#  'αἵ': 'haj',
#  'αἶ': 'aj',
#  'αἷ': 'haj',
#  'αὐ': 'au',
#  'αὑ': 'hau',
#  'αὒ': 'au',
#  'αὓ': 'hau',
#  'αὔ': 'au',
#  'αὕ': 'hau',
#  'αὖ': 'au',
#  'αὗ': 'hau',
#  'αὶ': 'aj',
#  'αὺ': 'au',
#  'αῖ': 'aj',
#  'αῦ': 'au',
#  'εί': 'ej',
#  'ει': 'ej',
#  'ευ': 'eu',
#  'εύ': 'eu',
#  'εἰ': 'ej',
#  'εἱ': 'hej',
#  'εἲ': 'ej',
#  'εἳ': 'hej',
#  'εἴ': 'ej',
#  'εἵ': 'hej',
#  'εἶ': 'ej',
#  'εἷ': 'hej',
#  'εὐ': 'eu',
#  'εὑ': 'heu',
#  'εὒ': 'eu',
#  'εὓ': 'heu',
#  'εὔ': 'eu',
#  'εὕ': 'heu',
#  'εὖ': 'eu',
#  'εὗ': 'heu',
#  'εὶ': 'ej',
#  'εὺ': 'eu',
#  'εῖ': 'ej',
#  'εῦ': 'eu',
#  'ηυ': 'eu',
#  'ηύ': 'eu',
#  'ηὐ': 'eu',
#  'ηὑ': 'heu',
#  'ηὔ': 'eu',
#  'ηὕ': 'eu',
#  'ηὖ': 'eu',
#  'ηὗ': 'heu',
#  'ηὺ': 'eu',
#  'ηῦ': 'eu',
#  'οί': 'oj',
#  'οι': 'oj',
#  'ου': 'u',
#  'ού': 'u',
#  'οἰ': 'oj',
#  'οἱ': 'hoj',
#  'οἲ': 'oj',
#  'οἳ': 'hoj',
# ...

# %%
for line in file.readlines():
    for word in line.split(' '):
        
        word = ''.join(word.split())
        for i in numbers:
            if i in word:
                word = word.replace(i, '')
        words.append(word)

# %%
newonllywords = ()

# %%
onlywords = set(words)

# %%
a = 0

# %%
len(onlywordsx)
# Out:
# 714

# %%
for i in onlywords:
    if len(i) < 2:
        onlywords.remove(i)

# %%
onlywords = list(onlywords)

# %%
onlywords
# Out:
# ['ἐφύτευσεν',
#  'πληθύνεσθε',
#  'ἰχθύων',
#  'νῦν',
#  'ταῖς',
#  'κατὰ',
#  'ἐξαγαγέτω',
#  'στερεώματι',
#  'πᾶσιν',
#  'μετέθηκεν',
#  'ζῶσαν',
#  'ἐξέβαλεν',
#  'με',
#  'κύριος',
#  'ποταμῷ',
#  'ἀντ’',
#  'τῶν',
#  'ἐκείνης',
#  'ὕπνωσεν',
#  'ἐνιαυτοὺς',
#  'διέλῃς',
#  'θυσίαις',
#  'δὲ',
#  'γνωστὸν',
#  'δύο',
#  'ἡμετέραν',
#  'παραλύσει',
#  'πάντα',
#  'ὃν',
#  'διηνοίχθησαν',
#  'ἄνθραξ',
#  'θυσίαν',
#  'ἐνωτίσασθέ',
#  'ἀφεθῆναί',
#  'πρωί',
#  'Καιν',
#  'μήποτε',
#  'χεῖρα',
#  'ἀποθάνητε',
#  'ἑαυτοῖς',
#  'ἑβδομήκοντα',
#  'σκότος',
#  'μώλωπα',
#  'ἐνεφύσησεν',
#  'τοῖς',
#  'ἀδελφὴ',
#  'ἔργοις',
#  'ἐργαζόμενος',
#  'ὀρθῶς',
#  'ἀποκτείνας',
#  'ἠπάτησέν',
#  'φωστῆρες',
#  'ἡμᾶς',
#  'καλὰ',
#  'ἐποίησας',
#  'γῆς',
#  'φυλάσσειν',
#  'πᾶσαν',
#  'αὐτοῦ',
#  'Ευιλατ',
#  'γὰρ',
#  'ἐκεῖ',
#  'φρονιμώτατος',
#  'μέσον',
#  'λέγουσα',
#  'ἑπτάκις',
#  'αὐτοὺς',
#  'κατανοῆσαι',
#  'λύπαις',
#  'υἱὸν',
#  'ἦν',
#  'γενηθήτωσαν',
#  'ξύλου',
#  'ὅρασιν',
# ...

# %%
for num in range(len(word)):
    dyf = word[num:num+2]
    if dyf in dyftongi.keys():
        print(dyf)
# Out:
# οί

# %%
newdyft['ευ']
# Out:
# 'eu'

# %%
wordsdict = {}

# %%
for word in onlywords[:10]:
    witem = ''
    for num in range(len(word)):
        dyf = word[num:num+2]
        let = word[num:num+1]
        if dyf in newdyft.keys():
            witem += str(newdyft[dyf])
                       
            
        elif word[num-1:num+1] in newdyft.keys():
            pass
        
        elif let in podstawowy.keys():
            witem += str(podstawowy[let])
            
    wordsdict[word] = witem

# %%
wordsdict
# Out:
# {'κατὰ': 'kata',
#  'μετέθηκεν': 'metetheken',
#  'νῦν': 'nyn',
#  'πληθύνεσθε': 'plethynesthe',
#  'πᾶσιν': 'pasin',
#  'στερεώματι': 'stereomati',
#  'ταῖς': 'tajs',
#  'ἐξαγαγέτω': 'eksagageto',
#  'ἐφύτευσεν': "e('f', 'ph')yteusen",
#  'ἰχθύων': "i('h', 'ch', 'kh')thyon"}

# %%
'ευ' in dyftongi.keys()
# Out:
# False
